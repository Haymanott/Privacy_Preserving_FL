# %%
import numpy as np
import torch
import flwr as fl
# Import other specific components as needed
# import utils
# from torchvision.models import segmentation
# from collections import OrderedDict
# from Pyfhel import Pyfhel
# from logging import WARNING
# from typing import Callable, Dict, List, Optional, Tuple, Union
# from flwr.common.logger import log
# from flwr.server.client_proxy import ClientProxy
# from flwr.server.strategy import FedAvg
# import os
# from strategy import FedAvgEncrypted
# from flwr.common import (
#     Code,
#     EvaluateIns,
#     EvaluateRes,
#     FitIns,
#     FitRes,
#     GetParametersIns,
#     GetParametersRes,
#     Status,
#     ndarrays_to_parameters,
#     parameters_to_ndarrays,
#     MetricsAggregationFn,
#     NDArrays,
#     Parameters,
#     Scalar,
#     Metrics,
# )
# import importlib
# import seaborn as sns
# import matplotlib.pyplot as plt
# import time
# import matplotlib.cm as cm
# import matplotlib.gridspec as gridspec
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[51], line 3
#       1 import numpy as np
#       2 import torch
# ----> 3 import flwr as fl
#       4 # Import other specific components as needed
#       5 # import utils
#       6 # from torchvision.models import segmentation
#    (...)
#      40 # import seaborn as sns
#      41 # import pandas as pd
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\__init__.py:20
#      15 """Flower main package."""
#      18 from flwr.common.version import package_version as _package_version
# ---> 20 from . import client, common, server, simulation
#      22 __all__ = [
#      23     "client",
#      24     "common",
#      25     "server",
#      26     "simulation",
#      27 ]
#      29 __version__ = _package_version
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\client\__init__.py:18
#       1 # Copyright 2020 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower client."""
# ---> 18 from .app import start_client as start_client
#      19 from .app import start_numpy_client as start_numpy_client
#      20 from .client import Client as Client
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\client\app.py:52
#      50 from flwr.common.typing import Fab, Run, UserConfig
#      51 from flwr.proto.clientappio_pb2_grpc import add_ClientAppIoServicer_to_server
# ---> 52 from flwr.server.superlink.fleet.grpc_bidi.grpc_server import generic_create_grpc_server
#      53 from flwr.server.superlink.state.utils import generate_rand_int_from_bytes
#      55 from .clientapp.clientappio_servicer import ClientAppInputs, ClientAppIoServicer
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\superlink\fleet\grpc_bidi\grpc_server.py:32
#      28 from flwr.proto.transport_pb2_grpc import (  # pylint: disable=E0611
#      29     add_FlowerServiceServicer_to_server,
#      30 )
#      31 from flwr.server.client_manager import ClientManager
# ---> 32 from flwr.server.superlink.driver.driver_servicer import DriverServicer
#      33 from flwr.server.superlink.fleet.grpc_adapter.grpc_adapter_servicer import (
#      34     GrpcAdapterServicer,
#      35 )
#      36 from flwr.server.superlink.fleet.grpc_bidi.flower_service_servicer import (
#      37     FlowerServiceServicer,
#      38 )
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\superlink\driver\driver_servicer.py:54
#      52 from flwr.server.superlink.ffs.ffs import Ffs
#      53 from flwr.server.superlink.ffs.ffs_factory import FfsFactory
# ---> 54 from flwr.server.superlink.state import State, StateFactory
#      55 from flwr.server.utils.validator import validate_task_ins_or_res
#      58 class DriverServicer(driver_pb2_grpc.DriverServicer):
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\superlink\state\__init__.py:18
#       1 # Copyright 2024 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower server state."""
# ---> 18 from .in_memory_state import InMemoryState as InMemoryState
#      19 from .sqlite_state import SqliteState as SqliteState
#      20 from .state import State as State
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\superlink\state\in_memory_state.py:29
#      27 from flwr.proto.task_pb2 import TaskIns, TaskRes  # pylint: disable=E0611
#      28 from flwr.server.superlink.state.state import State
# ---> 29 from flwr.server.utils import validate_task_ins_or_res
#      31 from .utils import generate_rand_int_from_bytes, make_node_unavailable_taskres
#      34 class InMemoryState(State):  # pylint: disable=R0902,R0904
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\__init__.py:19
#      15 """Flower server."""
#      18 from . import strategy
# ---> 19 from . import workflow as workflow
#      20 from .app import start_server as start_server
#      21 from .client_manager import ClientManager as ClientManager
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\workflow\__init__.py:18
#       1 # Copyright 2024 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Workflows."""
# ---> 18 from .default_workflows import DefaultWorkflow
#      19 from .secure_aggregation import SecAggPlusWorkflow, SecAggWorkflow
#      21 __all__ = [
#      22     "DefaultWorkflow",
#      23     "SecAggPlusWorkflow",
#      24     "SecAggWorkflow",
#      25 ]
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\workflow\default_workflows.py:37
#      34 from flwr.common.constant import MessageType, MessageTypeLegacy
#      36 from ..client_proxy import ClientProxy
# ---> 37 from ..compat.app_utils import start_update_client_manager_thread
#      38 from ..compat.legacy_context import LegacyContext
#      39 from ..driver import Driver
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\compat\__init__.py:18
#       1 # Copyright 2024 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower ServerApp compatibility package."""
# ---> 18 from .app import start_driver as start_driver
#      19 from .legacy_context import LegacyContext as LegacyContext
#      21 __all__ = [
#      22     "LegacyContext",
#      23     "start_driver",
#      24 ]
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\compat\app.py:28
#      25 from flwr.server.server_config import ServerConfig
#      26 from flwr.server.strategy import Strategy
# ---> 28 from ..driver import Driver
#      29 from .app_utils import start_update_client_manager_thread
#      32 def start_driver(  # pylint: disable=too-many-arguments, too-many-locals
#      33     *,
#      34     driver: Driver,
#    (...)
#      38     client_manager: Optional[ClientManager] = None,
#      39 ) -> History:
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\driver\__init__.py:20
#      18 from .driver import Driver
#      19 from .grpc_driver import GrpcDriver
# ---> 20 from .inmemory_driver import InMemoryDriver
#      22 __all__ = [
#      23     "Driver",
#      24     "GrpcDriver",
#      25     "InMemoryDriver",
#      26 ]
#
# File c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\driver\inmemory_driver.py:27
#      25 from flwr.common.typing import Run
#      26 from flwr.proto.node_pb2 import Node  # pylint: disable=E0611
# ---> 27 from flwr.server.superlink.state import StateFactory
#      29 from .driver import Driver
#      32 class InMemoryDriver(Driver):
#
# ImportError: cannot import name 'StateFactory' from partially initialized module 'flwr.server.superlink.state' (most likely due to a circular import) (c:\Users\Haymi\AppData\Local\Programs\Python\Python312\Lib\site-packages\flwr\server\superlink\state\__init__.py)

# %%
# import numpy as np
# np.float_ = np.float64
